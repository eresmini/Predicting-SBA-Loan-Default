# %%
import pandas as pd
from pathlib import Path

# %%
home_dir = Path(".").resolve()
# main_dir = home_dir.parent.parent
print(home_dir)
data_dir = str(home_dir) + "/data"
print(data_dir)
# Out:
# /home/jovyan/Emma/Capstone
# /home/jovyan/Emma/Capstone/data

# %%
df = pd.read_csv(str(data_dir)+'/'+ 'SBAnational.csv')
# Out:
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3552: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
np.random.seed(13)
df_small = df.sample(frac=0.54, replace=False)

# %%
df_small.head()
# Out:
#         LoanNr_ChkDgt                            Name     City State    Zip  \
# 10204      1071475005        Savannah Joe's BBQ, Inc.  BAYONNE    NJ   7002
# 269103     2877336009  KAREN'S KITCHEN & GOURMET SHOP  BEDFORD    NH   3110
# 219134     2549205010                       7 Station  HOUSTON    TX  77075
# 198717     2401714007                    GINA'S PIZZA   ALBANY    CA  94706
# 500179     4842063000        LINEAL AIR DIFFUSERS INC    UNION    MO  63084
#
#                                   Bank BankState   NAICS ApprovalDate  \
# 10204       BANK OF AMERICA NATL ASSOC        RI  722110    28-Sep-04
# 269103   MERRIMACK COUNTY SAVINGS BANK        NH  722110    29-Jun-07
# 219134  JPMORGAN CHASE BANK NATL ASSOC        IL  447110     2-Jul-07
# 198717   LOANS FROM OLD CLOSED LENDERS        DC       0    21-Oct-98
# 500179            UNITED BANK OF UNION        MO       0    12-May-92
#
#        ApprovalFY  ...  RevLineCr  LowDoc  ChgOffDate  DisbursementDate  \
# ...

# %%
df_small.to_csv('SBA_test.csv')
